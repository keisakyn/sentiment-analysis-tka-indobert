# %% [markdown]
# # Crawling Twitter Data based on **Search Keyword** Using `tweet-harvest`

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://cli.github.com/packages stable/main amd64 Packages [354 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,696 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.3 MB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,090 kB]
# Hit:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# ...

# %%
# Install dependencies yang missing
# !sudo apt-get update
# !sudo apt-get install -y \
    libatk1.0-0 \
    libatk-bridge2.0-0 \
    libatspi2.0-0 \
    libxcomposite1 \
    libxdamage1 \
    libxrandr2 \
    libgbm-dev \
    libxkbcommon-dev \
    libasound2

# Install Playwright browsers
# !npx playwright install-deps
# !npx playwright install
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
token = '78cedf56ad0373d932b27a03c3f76312ae6ab8d9'

# %%
# Crawl Data

filename = 'TKA.csv'
search_keyword = 'TKA  since:2025-12-25 until:2025-12-26 lang:in'
limit = 1000

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token "{token}"
# Out:
# ⠙⠹⠸⠼Tweet Harvest [v2.7.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/TKA.csv, renaming to ./tweets-data/TKA.old.csv
#
# -- Scrolling... (1)
# Filling in keywords: TKA  since:2025-12-25 until:2025-12-26 lang:in
#
#  (2) (3)
#
# Your tweets saved to: /content/tweets-data/TKA.csv
# Total tweets saved: 20
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/TKA.csv
# Total tweets saved: 40
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/TKA.csv
# Total tweets saved: 60
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/TKA.csv
# Total tweets saved: 80
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/TKA.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# %%
# Crawl Data

filename = 'TKA2.csv'
search_keyword = 'TKA since:2025-12-26 until:2025-12-27 lang:in'
limit = 1000

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token "{token}"
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.7.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/TKA2.csv, renaming to ./tweets-data/TKA2.old.csv
#
# -- Scrolling... (1)
# Filling in keywords: TKA since:2025-12-26 until:2025-12-27 lang:in
#
#  (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/TKA2.csv
# Total tweets saved: 20
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/TKA2.csv
# Total tweets saved: 40
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/TKA2.csv
# Total tweets saved: 60
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/TKA2.csv
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path2 = f"tweets-data/TKA2.csv"

# Read the CSV file into a pandas DataFrame
df2 = pd.read_csv(file_path2)

# %%
# Crawl Data

filename = 'TKA3.csv'
search_keyword = 'TKA since:2025-12-27 until:2025-12-28 lang:in'
limit = 1000

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token "{token}"
# Out:
# ⠙⠹⠸⠼⠴⠦⠧Tweet Harvest [v2.7.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/TKA3.csv, renaming to ./tweets-data/TKA3.old.csv
#
# -- Scrolling... (1)
# Filling in keywords: TKA since:2025-12-27 until:2025-12-28 lang:in
#
#  (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/TKA3.csv
# Total tweets saved: 20
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/TKA3.csv
# Total tweets saved: 40
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/TKA3.csv
# Total tweets saved: 60
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/TKA3.csv
# ...

# %%
# Specify the path to your CSV file
file_path3 = f"tweets-data/TKA3.csv"

# Read the CSV file into a pandas DataFrame
df3 = pd.read_csv(file_path3)

# %%
# Crawl Data

filename = 'TKA4.csv'
search_keyword = 'TKA stres since:2025-07-28 until:2025-12-29 lang:in'
limit = 1000

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token "{token}"
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋npm warn deprecated glob@7.2.3: Old versions of glob are not supported, and contain widely publicized security vulnerabilities, which have been fixed in the current version. Please update. Support for old versions may be purchased (at exorbitant rates) by contacting i@izs.me
# ⠋npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠙npm warn deprecated inflight@1.0.6: This module is not supported, and leaks memory. Do not use it. Check out lru-cache if you want a good and tested way to coalesce async requests by a key value, which is much more comprehensive and powerful.
# ⠙npm warn deprecated @playwright/test@1.41.1: Please update to the latest version of Playwright to test up-to-date browsers.
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸Tweet Harvest [v2.7.1]
#
# Research by Helmi Satria
# ...

# %%
import pandas as pd
file_path4 = f"tweets-data/TKA4.csv"
df4 = pd.read_csv(file_path4)
df4
# Out:
#     conversation_id_str                created_at  favorite_count  \
# 0   1977006083102421494  2025-10-11T13:39:15.000Z               1
# 1   1984998781256155205  2025-11-02T14:59:23.000Z               0
# 2   1985418740759241049  2025-11-03T18:48:09.000Z               1
# 3   1993266076378186144  2025-11-25T10:30:40.000Z               3
# 4   1985059661280899143  2025-11-02T19:01:18.000Z               1
# ..                  ...                       ...             ...
# 61  1985196318621589643  2025-11-03T04:04:20.000Z               0
# 62  1975231716727087588  2025-10-06T16:08:33.000Z               0
# 63  1992255892071596513  2025-11-22T15:36:33.000Z              11
# 64  1983732061543526447  2025-10-30T03:05:54.000Z              30
# 65  1980857367337279870  2025-10-22T04:42:53.000Z               1
#
#                                             full_text               id_str  \
# 0   my #progress, agak stres dikit tapi asiek ea.....  1977006083102421494
# ...

# %%
# Crawl Data

filename = 'TKA5.csv'
search_keyword = 'TKA since:2025-12-29 until:2026-01-05 lang:in'
limit = 1000

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -l {limit} --token "{token}"
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.7.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/TKA5.csv, renaming to ./tweets-data/TKA5.old.csv
#
# -- Scrolling... (1)
# Filling in keywords: TKA since:2025-12-29 until:2026-01-05 lang:in
#
#  (2) (3)
#
# Your tweets saved to: /content/tweets-data/TKA5.csv
# Total tweets saved: 20
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/TKA5.csv
# Total tweets saved: 40
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/TKA5.csv
# Total tweets saved: 60
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/TKA5.csv
# ...

# %%
file_path5 = f"tweets-data/TKA5.csv"
df5 = pd.read_csv(file_path5)

# %%
# Gabungkan seluruh df
# dfa = pd.read_csv(f"dataset_tka.csv")
df_combined = pd.concat([df, df2, df3,df4, df5], ignore_index=True)

print(f"Data pertama: {len(df)} rows")
print(f"Data kedua: {len(df2)} rows")
print(f"Data ketiga: {len(df3)} rows")
print(f"Data ke4: {len(df4)} rows")
print(f"Data ke5: {len(df5)} rows")
print(f"Data gabungan: {len(df_combined)} rows")
display(df_combined.head())
# Out:
# Data pertama: 129 rows
# Data kedua: 114 rows
# Data ketiga: 112 rows
# Data ke4: 140 rows
# Data ke5: 138 rows
# Data gabungan: 633 rows
#    conversation_id_str                created_at  favorite_count  \
# 0  2004180355738194293  2025-12-25T13:20:07.000Z             310
# 1  2004006706125078693  2025-12-25T01:50:06.000Z               3
# 2  2004288566843576733  2025-12-25T20:30:06.000Z               1
# 3  2004174160394907801  2025-12-25T12:55:30.000Z               0
# 4  2004178245085024581  2025-12-25T13:11:44.000Z               7
#
#                                            full_text               id_str  \
# 0  sch! ngeliat nilai rata-rata nasional yg jeblo...  2004180355738194293
# 1  Ptn! TKA kemaren aku ngambil kimia biologi di ...  2004006706125078693
# 2  PTN! denger denger tka gajadi buat snbp 😔 http...  2004288566843576733
# 3  mnrt gua jg tka gaakan keluar besok jir org ga...  2004174160394907801
# ...

# %%
# Hapus duplikat berdasarkan kolom 'id' (jika ada)
if 'id' in df_combined.columns:
    df_combined = df_combined.drop_duplicates(subset=['id'])
    print(f"Setelah hapus duplikat: {len(df_combined)} rows")
else:
    # Jika tidak ada kolom 'id', hapus duplikat berdasarkan semua kolom
    df_combined = df_combined.drop_duplicates()
    print(f"Setelah hapus duplikat: {len(df_combined)} rows")

display(df_combined)
# Out:
# Setelah hapus duplikat: 633 rows
#      conversation_id_str                created_at  favorite_count  \
# 0    2004180355738194293  2025-12-25T13:20:07.000Z             310
# 1    2004006706125078693  2025-12-25T01:50:06.000Z               3
# 2    2004288566843576733  2025-12-25T20:30:06.000Z               1
# 3    2004174160394907801  2025-12-25T12:55:30.000Z               0
# 4    2004178245085024581  2025-12-25T13:11:44.000Z               7
# ..                   ...                       ...             ...
# 628  2007178581320053230  2026-01-02T19:54:00.000Z               0
# 629  2007429742795075606  2026-01-03T12:32:01.000Z               1
# 630  2007644647603261670  2026-01-04T02:45:58.000Z               0
# 631  2007317892023595297  2026-01-03T05:07:34.000Z               0
# 632  2007276816105648437  2026-01-03T02:24:21.000Z               0
#
#                                              full_text               id_str  \
# ...

# %%
df_combined = df_combined[df_combined['lang'] == 'in']

# %%
combined_filename = "TKA_sabtu 13.csv"
df_combined.to_csv(f"tweets-data/{combined_filename}", index=False)

print(f"Data gabungan disimpan sebagai: {combined_filename}")
print(f"Total data: {len(df_combined)} tweets")
# Out:
# Data gabungan disimpan sebagai: TKA_sabtu 13.csv
# Total data: 633 tweets

# %%
dfa = pd.read_csv(f"TKA_sabtu 1.csv")
dfb = pd.read_csv(f"TKA_sabtu 2.csv")
dfc = pd.read_csv(f"TKA_sabtu 3.csv")
dfd = pd.read_csv(f"TKA_sabtu 4.csv")
dfe = pd.read_csv(f"TKA_sabtu 5.csv")
dff = pd.read_csv(f"TKA_sabtu 6.csv")
dfg = pd.read_csv(f"TKA_sabtu 7.csv")
dfh = pd.read_csv(f"TKA_sabtu 8.csv")
dfi = pd.read_csv(f"TKA_sabtu 9.csv")
dfj = pd.read_csv(f"TKA_sabtu 10.csv")
dfk = pd.read_csv(f"TKA_sabtu 11.csv")
dfl = pd.read_csv(f"TKA_sabtu 12.csv")
dfm = pd.read_csv(f"TKA_sabtu 13.csv")
dfn = pd.read_csv(f"dataset_tka.csv")

# %%
list_df = [dfa, dfb, dfc, dfd, dfe, dff, dfg, dfh, dfi, dfj, dfk, dfl, dfm, dfn]
df = pd.concat(list_df, ignore_index=True)

# %% [markdown]
# ## analisis awal

# %%
import pandas as pd

# %%
df = pd.read_csv(f"dataset_tka (1).csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4465 entries, 0 to 4464
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      4465 non-null   float64
#  1   created_at               4465 non-null   object
#  2   favorite_count           4465 non-null   int64
#  3   full_text                4465 non-null   object
#  4   id_str                   4465 non-null   float64
#  5   image_url                0 non-null      float64
#  6   in_reply_to_screen_name  164 non-null    object
#  7   lang                     4465 non-null   object
#  8   location                 0 non-null      float64
#  9   quote_count              4465 non-null   int64
#  10  reply_count              4465 non-null   int64
#  11  retweet_count            4465 non-null   int64
#  12  tweet_url                4465 non-null   object
#  13  user_id_str              4465 non-null   float64
# ...

# %%
df = df.drop_duplicates(subset=['full_text'])
df = df.dropna(subset=['full_text'])
df.reset_index(drop=True, inplace=True)
print("Jumlah data setelah hapus duplikat:", len(df))
display(df)
# Out:
# Jumlah data setelah hapus duplikat: 4465
#       conversation_id_str                created_at  favorite_count  \
# 0            1.930000e+18  2025-06-15T13:36:00.000Z             128
# 1            1.930000e+18  2025-06-16T10:01:07.000Z              31
# 2            1.930000e+18  2025-06-17T00:11:41.000Z              36
# 3            1.940000e+18  2025-06-17T22:45:05.000Z               0
# 4            1.930000e+18  2025-06-17T05:30:36.000Z               0
# ...                   ...                       ...             ...
# 4460         1.990000e+18  2025-11-26T10:56:44.000Z               0
# 4461         1.990000e+18  2025-11-24T09:04:51.000Z               0
# 4462         1.990000e+18  2025-11-10T11:39:14.000Z               0
# 4463         2.000000e+18  2025-12-01T12:39:47.000Z               0
# 4464         1.990000e+18  2025-11-05T01:35:00.000Z               0
#
#                                               full_text        id_str  \
# ...

# %%
# Membuat dataframe sementara berisi data yang TIDAK mengandung 'TKA'
df_dropped = df[~df['full_text'].str.contains('TKA' , case=False, na=False)]

# Menampilkan data yang akan dibuang
print(f"Jumlah data yang akan di-drop: {len(df_dropped)} baris")
display(df_dropped[['username', 'full_text']].head(70)) # Melihat 20 sampel teratas
# Out:
# Jumlah data yang akan di-drop: 161 baris
#              username                                          full_text
# 22       motherlander  Semoga yang suka mengintimidasi dan meretas hi...
# 54    theyycallmebass                 Sampe salah fokus kamera gueee!! 😭
# 73    theyycallmebass          Loh yang penting kan KOOPERATIF dongggggg
# 147   theyycallmebass           Yah ketololan SMESCO lagi ini mah wkwkwk
# 160   theyycallmebass  Sori bgt jadi terkesan mempermasalahkan hal re...
# ...               ...                                                ...
# 1910     Anaxagoras_s  Kemaleman kayaknya deh (((^_^;) but yang masih...
# 1949  theyycallmebass               Sori sori aje nih bos @L_MarshaJKT48
# 2006     Anaxagoras_s   TIFOSI BERSINAR!!\nbentar mau nyiapin jj buat sw
# 2092     Anaxagoras_s                   Mbb ya kakk! Terimakasih banyakk
# 2131  theyycallmebass  Duluan w ngantuk besop masih ngangstor. Jan ga...
#
# [70 rows x 2 columns]

# %%
import re
promo = [
    "harga", "tryout", "bimbel", "les", "kelas gratis",
    "daftar sekarang", "diskon", "promo", "open kelas",
    "pendaftaran", "link di bio", "hubungi", "wa",
    "wts","wtb","garansi","pricelist",
    "whatsapp", "t.me", "telegram", "zoom class",
    "ruangguru", "zenius", "brain academy",
    "kode promo", "tutor", "privat", "booking",
    "join kelas", "kelas intensif", "ebook gratis",
    "jualan", "open jasa", "admin", "slot terbatas",
    "detik", "kompas", "cnn", "tribun", "tempo",
    "liputan6", "kumparan", "tvone", "metrotv", "china",
    "pemerintah","pemimpin","dzalim","akbar","prabowo",
    "asing","kritik", "jokowi", "tirto","pejabat","antek",
    "asing","stafsus", "korupsi", "kpk","kemnaker","disnaker",
    "disnakertrans","menaker","menakertrans","imigrasi","visa",
    "pemerasan","tersangka","buruh","tki","tkw","deportasi","outsourcing"
]

def cek_spam(text):
    text = str(text).lower()
    for word in promo:
        if re.search(r'\b' + re.escape(word) + r'\b', text):
            return True
    return False

# %%
df_clean = df[~df['full_text'].apply(cek_spam)]
df_clean.reset_index(drop=True, inplace=True)

print("Jumlah data awal:", len(df))
print("Jumlah data setelah hapus promosi:", len(df_clean))
# Out:
# Jumlah data awal: 4465
# Jumlah data setelah hapus promosi: 4444

# %%
#hapus link
df_clean = df_clean[~df_clean['full_text'].str.contains("http", case=False)]
#hapus twit pendek
df_clean = df_clean[df_clean['full_text'].str.len() > 10]

# %%
#reset index
df_clean = df_clean.reset_index(drop=True)
df_clean
# Out:
#       conversation_id_str                created_at  favorite_count  \
# 0            1.930000e+18  2025-06-15T13:36:00.000Z             128
# 1            1.930000e+18  2025-06-16T10:01:07.000Z              31
# 2            1.930000e+18  2025-06-17T00:11:41.000Z              36
# 3            1.940000e+18  2025-06-17T22:45:05.000Z               0
# 4            1.930000e+18  2025-06-17T05:30:36.000Z               0
# ...                   ...                       ...             ...
# 4438         1.990000e+18  2025-11-26T10:56:44.000Z               0
# 4439         1.990000e+18  2025-11-24T09:04:51.000Z               0
# 4440         1.990000e+18  2025-11-10T11:39:14.000Z               0
# 4441         2.000000e+18  2025-12-01T12:39:47.000Z               0
# 4442         1.990000e+18  2025-11-05T01:35:00.000Z               0
#
#                                               full_text        id_str  \
# 0     Sch! Guys aku ada grup belajar buat angkatan 2...  1.930000e+18
# ...

# %%
# Konversi kolom "created_at" ke tipe datetime
df_clean["created_at"] = pd.to_datetime(df["created_at"])
# Mengurutkan data dari yang paling lama ke yang terbaru
df_sorted = df_clean.sort_values(by="created_at", ascending=True)

print(df_sorted[["created_at"]].head())  # 5 data teratas
print(df_sorted[["created_at", "full_text"]].tail(70))  # 5 data terbawah
# Out:
#                     created_at
# 4078 2025-05-29 09:06:06+00:00
# 3790 2025-05-29 14:24:07+00:00
# 4091 2025-05-29 17:17:52+00:00
# 4054 2025-05-29 18:02:02+00:00
# 4081 2025-05-30 03:15:56+00:00
#                     created_at  \
# 3461 2025-12-31 17:08:19+00:00
# 3454 2025-12-31 17:46:01+00:00
# 3455 2025-12-31 18:00:57+00:00
# 3476 2026-01-01 03:15:05+00:00
# 3474 2026-01-01 09:12:14+00:00
# ...                        ...
# 3472 2026-01-04 17:05:35+00:00
# 3485 2026-01-04 17:19:54+00:00
# 3465 2026-01-04 19:30:24+00:00
# 3445 2026-01-04 22:32:08+00:00
# 3468 2026-01-04 23:46:32+00:00
#
#                                               full_text
# 3461  Aku sakit dari bulan November sampai hari ini ...
# 3454  annyeonghaseyo ak akn aktif terus smpai mpls n...
# 3455           sebelum tidur alangkah baiknya vote dulu
# 3476  gimana kalo buat Free Class untuk persiapan TK...
# 3474  Social Media should be restricted for those un...
# ...

# %%
df_sorted.reset_index(drop=True, inplace=True)

# %%
df_sorted
# Out:
#       conversation_id_str                created_at  favorite_count  \
# 0            1.940000e+18 2025-05-29 09:06:06+00:00               0
# 1            1.960000e+18 2025-05-29 14:24:07+00:00               2
# 2            1.940000e+18 2025-05-29 17:17:52+00:00               0
# 3            1.930000e+18 2025-05-29 18:02:02+00:00               0
# 4            1.940000e+18 2025-05-30 03:15:56+00:00               0
# ...                   ...                       ...             ...
# 4438         2.010000e+18 2026-01-04 17:05:35+00:00               0
# 4439         2.010000e+18 2026-01-04 17:19:54+00:00               1
# 4440         2.010000e+18 2026-01-04 19:30:24+00:00               0
# 4441         2.010000e+18 2026-01-04 22:32:08+00:00               1
# 4442         2.010000e+18 2026-01-04 23:46:32+00:00               1
#
#                                               full_text        id_str  \
# 0                        YA ALLAH CAPEKBGTT BELAJAR TKA  1.940000e+18
# ...

# %%
df_sorted.to_csv("dataset_final.csv", index=False)
